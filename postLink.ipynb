# %%
import pandas as pd
import numpy as np

post = pd.read_csv('logbookFinal.csv')
blenderStock = pd.read_csv('blendstock.csv')


locations = blenderStock['Location'].values
random_locations = np.random.choice(locations, size=len(post), replace=True)
post['Destination'] = random_locations
post = post.sample(frac=1).reset_index(drop=True)
post['Sequence'] = range(1, len(post) + 1)
post = post.drop(['Task Duration (Minutes)', 'Task Duration (Hours)'], axis=1)

post = post[['Blend Code', 'Sequence', 'Destination', 'Quantity', 'Line']]

# %%
post
# Out:
#    Blend Code  Sequence  Quantity      Line         Destination
# 0       B0005         1     28800    Line 8           Warehouse
# 1       B0002         2     19440    Line 6           Warehouse
# 2       B0006         3     17820   Line 11              Silo D
# 3       B0005         4     22272   Line 10              Silo E
# 4       B0004         5      6509    Line 9              Silo A
# 5       B0010         6      5040    Line 1           Warehouse
# 6       B0001         7     15587    Line 1              Silo D
# 7       B0004         8     13680   Line 11  Transfer Station D
# 8       B0011         9     15450    Line 5              Silo A
# 9       B0001        10     30780    Line 7           Warehouse
# 10      B0006        11      8640    Line 4              Silo A
# 11      B0012        12      1302    Line 4              Silo C
# 12      B0010        13      5040    Line 2           Warehouse
# 13      B0007        14     12960    Line 7              Silo A
# 14      B0004        15     13680    Line 3           Warehouse
# 15      B0004        16     13680    Line 2              Silo D
# 16      B0005        17     28800    Line 7              Silo E
# 17      B0006        18      3240    Line 3           Warehouse
# 18      B0004        19     24960    Line 4           Warehouse
# 19      B0003        20     33360   Line 10           Warehouse
# 20      B0006        21      8370    Line 1              Silo B
# 21      B0007        22     12960    Line 6              Silo C
# 22      B0006        23      8370    Line 2           Warehouse
# 23      B0005        24     28800    Line 9  Transfer Station D
# 24      B0005        25     28800    Line 5              Silo C
# 25      B0004        26      6509    Line 3              Silo C
# 26      B0008        27      8640    Line 5              Silo C
# 27      B0001        28     14040    Line 8              Silo A
# 28      B0005        29     28800    Line 6              Silo F
