# %%
import pandas as pd
import numpy as np

post = pd.read_csv('logbookFinal.csv')
blenderStock = pd.read_csv('blendstock.csv')


locations = blenderStock['Location'].values
random_locations = np.random.choice(locations, size=len(post), replace=True)
post['Destination'] = random_locations
post = post.sample(frac=1).reset_index(drop=True)
post['Sequence'] = range(1, len(post) + 1)
post = post.drop(['Task Duration (Minutes)', 'Task Duration (Hours)'], axis=1)

post = post[['Blend Code', 'Sequence', 'Destination', 'Quantity', 'Line']]

# %%
post
# Out:
#    Blend Code  Sequence         Destination  Quantity      Line
# 0       B0005         1           Warehouse     28800    Line 9
# 1       B0004         2  Transfer Station D      6509    Line 3
# 2       B0004         3           Warehouse      6509    Line 9
# 3       B0010         4           Warehouse      5040    Line 1
# 4       B0001         5           Warehouse     15587    Line 1
# 5       B0004         6              Silo B     24960    Line 4
# 6       B0003         7           Warehouse     33360   Line 10
# 7       B0006         8              Silo E      3240    Line 3
# 8       B0004         9           Warehouse     13680   Line 11
# 9       B0005        10           Warehouse     28800    Line 7
# 10      B0005        11              Silo C     28800    Line 6
# 11      B0005        12           Warehouse     22272   Line 10
# 12      B0008        13              Silo A      8640    Line 5
# 13      B0005        14           Warehouse     28800    Line 5
# 14      B0006        15  Transfer Station D     17820   Line 11
# 15      B0010        16           Warehouse      5040    Line 2
# 16      B0004        17           Warehouse     13680    Line 3
# 17      B0011        18           Warehouse     15450    Line 5
# 18      B0005        19              Silo D     28800    Line 8
# 19      B0007        20           Warehouse     12960    Line 7
# 20      B0002        21           Warehouse     19440    Line 6
# 21      B0006        22           Warehouse      8370    Line 2
# 22      B0001        23           Warehouse     14040    Line 8
# 23      B0001        24              Silo C     30780    Line 7
# 24      B0006        25  Transfer Station A      8640    Line 4
# 25      B0007        26           Warehouse     12960    Line 6
# 26      B0006        27           Warehouse      8370    Line 1
# 27      B0012        28              Silo F      1302    Line 4
# 28      B0004        29              Silo C     13680    Line 2
